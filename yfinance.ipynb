# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
pip install yfinance
# Out:
# ...
#   Obtaining dependency information for yfinance from https://files.pythonhosted.org/packages/1b/0f/77716aa9dd84bb1aa5e93c87122af1de89697b6231f6d01d58d4e7c03c14/yfinance-0.2.36-py2.py3-none-any.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.6/314.6 kB 497.4 kB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 483.4 kB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 517.0 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.4/72.4 kB 1.2 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import yfinance as yf
df = yf.download('AAPL',start = '2024-01-01', end='2024-01-31')
df.head
# Out:
# [*********************100%%**********************]  1 of 1 completed
# <bound method NDFrame.head of                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-01-02  187.149994  188.440002  183.889999  185.639999  185.403412
# 2024-01-03  184.220001  185.880005  183.429993  184.250000  184.015198
# 2024-01-04  182.149994  183.089996  180.880005  181.910004  181.678177
# 2024-01-05  181.990005  182.759995  180.169998  181.179993  180.949097
# 2024-01-08  182.089996  185.600006  181.500000  185.559998  185.323517
# 2024-01-09  183.919998  185.149994  182.729996  185.139999  184.904053
# 2024-01-10  184.350006  186.399994  183.919998  186.190002  185.952713
# 2024-01-11  186.539993  187.050003  183.619995  185.589996  185.353485
# 2024-01-12  186.059998  186.740005  185.190002  185.919998  185.683060
# 2024-01-16  182.160004  184.259995  180.929993  183.630005  183.395981
# 2024-01-17  181.270004  182.929993  180.300003  182.679993  182.447189
# ...

# %%
df.head(10)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-01-02  187.149994  188.440002  183.889999  185.639999  185.403412
# 2024-01-03  184.220001  185.880005  183.429993  184.250000  184.015198
# 2024-01-04  182.149994  183.089996  180.880005  181.910004  181.678177
# 2024-01-05  181.990005  182.759995  180.169998  181.179993  180.949097
# 2024-01-08  182.089996  185.600006  181.500000  185.559998  185.323517
# 2024-01-09  183.919998  185.149994  182.729996  185.139999  184.904053
# 2024-01-10  184.350006  186.399994  183.919998  186.190002  185.952713
# 2024-01-11  186.539993  187.050003  183.619995  185.589996  185.353485
# 2024-01-12  186.059998  186.740005  185.190002  185.919998  185.683060
# 2024-01-16  182.160004  184.259995  180.929993  183.630005  183.395981
#
#               Volume
# Date
# 2024-01-02  82488700
# 2024-01-03  58414500
# 2024-01-04  71983600
# 2024-01-05  62303300
# 2024-01-08  59144500
# 2024-01-09  42841800
# ...

# %%
jan1 = pd.to_datetime('2024, 1 ,1')
jan1.day_name()
# Out:
# 'Monday'

# %%
a = df['High'] 
b = df['Low'] 
c = df['Adj Close'] 
plt.figure(figsize = (15,5))
plt.title('Apple Stock for January 2024')
plt.xlabel('Year')
plt.ylabel('Price')
plt.plot(c)
plt.show()

# %%
nike = yf.download('NKE',start ='202-1-1',end = '2024-1-31')
nike.head(10)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close  Adj Close   Volume
# Date
# 2020-01-02  101.360001  102.209999  101.019997  102.199997  98.143021  5644100
# 2020-01-03  100.589996  102.000000  100.309998  101.919998  97.874123  4541800
# 2020-01-06  100.949997  101.839996  100.870003  101.830002  97.787712  4612400
# 2020-01-07  101.809998  102.739998  100.809998  101.779999  97.739693  6719900
# 2020-01-08  101.309998  102.139999  100.849998  101.550003  97.518814  4942200
# 2020-01-09  101.940002  102.410004  101.389999  101.480003  97.451614  5007500
# 2020-01-10  101.889999  101.930000  100.760002  100.900002  96.894623  5135300
# 2020-01-13  101.000000  102.339996  100.820000  102.160004  98.104614  6722400
# 2020-01-14  102.449997  103.889999  102.349998  102.919998  98.834435  5088500
# 2020-01-15  103.250000  103.699997  102.480003  102.790001  98.709587  4209200

# %%
c = nike['Adj Close'] 
plt.figure(figsize = (15,5))
plt.title('Nike Stock for January 2024')
plt.xlabel('Year')
plt.ylabel('Price')
plt.plot(c,color='green')
plt.show()

# %%
theta = np.arange(0, (2 * np.pi), 0.01) #generating an array of evenly spaced floats
r= 2

for radian in theta:
    plt.polar(radian,r)
