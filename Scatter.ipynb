# %%
import numpy as np
import matplotlib.pyplot as plt

a = np.random.randint(10,60,20)
b = np.random.randint(40,80,20)

plt.scatter(a,b,c='red',marker='*')
plt.show()

# %%
# Out:
# The number of angles:  5
# Angle 1  10
# Angle 2  20
# Angle 3  40
# Angle 4  90
# Angle 5  150

# %%
import pandas as pd
df = pd.DataFrame({'col1': [1,3,11,2], 'col2': [9,23,0,2]})
df
# Out:
#    col1  col2
# 0     1     9
# 1     3    23
# 2    11     0
# 3     2     2
